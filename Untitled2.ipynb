# %% [markdown]
# <a href="https://colab.research.google.com/github/waldirjuniorfernandes16-glitch/atividades-python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
disciplina = input("Digite o nome da disciplina: ")
conteudo = input("Digite o conteúdo estudado: ")
atividade = input("Digite o número da atividade: ")
print("\n--- Informações da atividade ---")
print("Disciplina:", disciplina)
print("Conteúdo:", conteudo)
print("Atividade:", atividade)
# Out:
# Digite o nome da disciplina: História
# Digite o conteúdo estudado: Egito
# Digite o número da atividade: 02
#
# --- Informações da atividade ---
# Disciplina: História
# Conteúdo: Egito
# Atividade: 02
