# %% [markdown]
# <a href="https://colab.research.google.com/github/waldirjuniorfernandes16-glitch/atividades-python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá, mundo!")
print("Curso Técnico em Infomartica")
# Out:
# Olá, mundo!
# Curso Técnico em Infomartica

# %%
disciplina = input("Digite o nome da disciplina: ")
conteudo = input("Digite o conteúdo estudado: ")
atividade = input("Digite o número da atividade: ")
print("\n--- Informações da atividade ---")
print("Disciplina:", disciplina)
print("Conteúdo:", conteudo)
print("Atividade:", atividade)
# Out:
# Digite o nome da disciplina: Programação
# Digite o conteúdo estudado: Introdução a python
# Digite o número da atividade: 01
#
# --- Informações da atividade ---
# Disciplina: Programação
# Conteúdo: Introdução a python
# Atividade: 01

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print("Resultado:", soma)
# Out:
# Resultado: 30
